# %%
# !pip install jsonapi_client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jsonapi_client in c:\users\oskar\appdata\roaming\python\python311\site-packages (0.9.9)
# Requirement already satisfied: requests in c:\users\oskar\appdata\roaming\python\python311\site-packages (from jsonapi_client) (2.29.0)
# Requirement already satisfied: jsonschema in c:\users\oskar\appdata\roaming\python\python311\site-packages (from jsonapi_client) (4.18.4)
# Requirement already satisfied: aiohttp in c:\users\oskar\appdata\roaming\python\python311\site-packages (from jsonapi_client) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from aiohttp->jsonapi_client) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from jsonschema->jsonapi_client) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from jsonschema->jsonapi_client) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from jsonschema->jsonapi_client) (0.9.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from requests->jsonapi_client) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from requests->jsonapi_client) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from requests->jsonapi_client) (2022.12.7)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
inputBioms = ["root:Host-associated:Human:Digestive system:Oral:Subgingival plaque","root:Host-associated:Human:Digestive system:Oral:Supragingival plaque"]

biomNameMapping =  {
    "root:Host-associated:Human:Digestive system:Oral:Subgingival plaque": "biom1",
    "root:Host-associated:Human:Digestive system:Oral:Supragingival plaque": "biom2"
}

runName = "run_01"

max_sample_count = 500

# %%
# Imports
# !pip install conorm

from jsonapi_client import Session
import pandas as pd
import requests
import os
import numpy as np
import conorm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: conorm in c:\users\oskar\appdata\roaming\python\python311\site-packages (1.2.0)
# Requirement already satisfied: numpy in c:\users\oskar\appdata\roaming\python\python311\site-packages (from conorm) (1.24.3)
# Requirement already satisfied: pandas in c:\users\oskar\appdata\roaming\python\python311\site-packages (from conorm) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from pandas->conorm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from pandas->conorm) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from pandas->conorm) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\oskar\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->conorm) (1.16.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
###################
# Definie Functions
###################

########################################################
# input: biom string from MGnify
# https://www.ebi.ac.uk/metagenomics/browse/biomes/
# example: GetBiomSamplesByIds(root:Engineered:Bioreactor)
#
#
# output: df with the first <max_sample_count> 
########################################################
def GetBiomSamplesByIds(biom_id: str):
    with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
        i = 0
        biomes_dfs = []
        for r in mgnify.iterate(f'biomes/{biom_id}/samples'):
            biom_df = pd.json_normalize(r.json)
            biom_df['url'] = str(r.links.self)
            biomes_dfs.append(biom_df)
            i += 1
            if(i == max_sample_count):
                break
    main_biomes_df = pd.concat(biomes_dfs)
    return main_biomes_df

########################################################
# input: study ACCESSION from mgnify
# https://www.ebi.ac.uk/metagenomics/browse/studies
# example: GetBiomSamplesByIds(MGYS00006539)
#
#
# output: list with 2 objects
# when output[0] == None, we have a study without any analysis data
# when output[0] == 1,  output[1] = df with all meta-analysis Informations (accession, date, version, ...) for each sample in the study
########################################################

def GetAnalysisFromStudy(_study_id):
    with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
        biomes_dfs = []
        for r in mgnify.iterate(f'studies/{_study_id}/analyses'):
            biom_df = pd.json_normalize(r.json)
            biom_df['url'] = str(r.links.self)
            biomes_dfs.append(biom_df)
    # testing if study has no analysis data
    if(biomes_dfs == []):
        return [None,None]
    main_biomes_df = pd.concat(biomes_dfs)

    return [1,main_biomes_df]

# %%
for biom in inputBioms:
    df_samples = GetBiomSamplesByIds(biom)

    sample_accessions = (df_samples['attributes.accession'].to_list())

    studies = df_samples['relationships.studies.data'].to_list()
    ####################
    # for each of the studies we test if they have analysis data.
    # if so we save the data in <study_analaysises>,
    # until we have data for every sample.
    ####################

    # list of df with analysis data from studys
    study_analaysises = []
    # study-accessions from studys without analysis
    studies_without_analysis = []
    # study-accessions from studys having analysis data in <study_analaysises>
    studies_Ids = []

    for study in studies:
        # list of studies for sample
        s_ids_sample = []
        for s in str(study).split("'"):
            if('MGYS' in s):
                s_ids_sample.append(s) 
        # for each study
        for st in s_ids_sample:
            # test if we havent checked study
            if(st in studies_Ids):
                # we allready have analysis data for this study
                break
            if(st not in studies_without_analysis):
                # Get analysis data for this study
                study_analaysis = GetAnalysisFromStudy(st)
                if(study_analaysis[0] == None):
                    # discard if study has no analysis
                    studies_without_analysis.append(st)
                    continue
                # keep if study has analysis
                studies_Ids.append(st)
                study_analaysises.append(study_analaysis[1])
                break
    # Merge all analysis data into one large df
    study_analaysis = pd.concat(study_analaysises)
    analysis_accesions = []
    for sample_acc in sample_accessions:
        acc = study_analaysis[study_analaysis['relationships.sample.data.id'] == sample_acc]['attributes.accession'].to_list()
        analysis_accesions.append([len(acc),acc])
    analysis_accesions

    ##################################
    # for each of of our samples we try to get the taxonomic assingments from MGnify
    # if none of the analysis accessions of a sample return a file, we skip the sample
    # (this happens when for e.g. the version of the MGnify pipeline is to old)
    #
    # Trying for "OTUs and taxonomic assignments for SSU rRNA" and "All reads encoding SSU rRNA" beacuse of different pipeline versions
    #
    # all Analysis files are saved in 'outputs/collection', so that they are automatically exported into Galaxy as one Collection
    #
    # analysis files are saved under 'outputs/collection/<analysis-accession>-<sample-accession>.tsv'
    ##################################

    # for each of our samples
    for analysis_sample in analysis_accesions:
        url = ""
        # for each analysis-accession for the sample
        for analysis_accession in analysis_sample[1]:
            print(f"start grab for {analysis_accession}")
            
            # Get all downloads for one analysis
            with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
                
                dfs = []
                for r in mgnify.iterate(f'analyses/{analysis_accession}/downloads'):
                    df = pd.json_normalize(r.json)
                    df['url'] = str(r.links.self)
                    dfs.append(df)
                
            main_df = pd.concat(dfs)

            data_type = "TSV"
            data_label = "OTUs and taxonomic assignments for SSU rRNA"
            
            # get URL for data_label = "OTUs and taxonomic assignments for SSU rRNA"
            c1 = main_df["attributes.file-format.name"] == data_type
            c2 = main_df["attributes.description.description"] == data_label
            if(main_df.loc[(c1 & c2), "url"].size == 0):
                # if we dont get a match try the same with data_label = 'All reads encoding SSU rRNA'
                data_label = "All reads encoding SSU rRNA"
                c2 = main_df["attributes.description.description"] == data_label
                if(main_df.loc[(c1 & c2), "url"].size == 0):
                    continue
                else:
                    url = main_df.loc[(c1 & c2), "url"].iloc[0]
                    break
            url = main_df.loc[(c1 & c2), "url"].iloc[0]
            break

        if(url == ""):
            print(f'no analysis found for {analysis_sample}')
            continue

        ##########################
        # download the data
        #########################

        data_output_folder = f'outputs/collection/{runName}/{biomNameMapping[biom]}'
        if(not os.path.exists(data_output_folder)):
            os.makedirs(data_output_folder, exist_ok=True)

        response = requests.get(url)

        if not response:
            print(f"Could not download file, got response: {response.status_code}")
            break
            
        print(url)
        data_output_path = os.path.join(data_output_folder, f"{analysis_accession}-{study_analaysis[study_analaysis['attributes.accession'] == analysis_accession]['relationships.sample.data.id'].to_list()[0]}.tsv")
        with open(data_output_path, "w") as f:
            f.write(response.text)
# Out:
# start grab for MGYA00661793
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661793/file/ERZ14207391_FASTA_SSU_OTU.tsv
# start grab for MGYA00661792
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661792/file/ERZ14207393_FASTA_SSU_OTU.tsv
# start grab for MGYA00661791
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661791/file/ERZ14207392_FASTA_SSU_OTU.tsv
# start grab for MGYA00661789
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661789/file/ERZ14207394_FASTA_SSU_OTU.tsv
# start grab for MGYA00661787
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661787/file/ERZ14207366_FASTA_SSU_OTU.tsv
# start grab for MGYA00661785
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661785/file/ERZ14207367_FASTA_SSU_OTU.tsv
# start grab for MGYA00661784
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661784/file/ERZ14207368_FASTA_SSU_OTU.tsv
# start grab for MGYA00661783
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661783/file/ERZ14207369_FASTA_SSU_OTU.tsv
# start grab for MGYA00661782
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661782/file/ERZ14207372_FASTA_SSU_OTU.tsv
# start grab for MGYA00661780
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661780/file/ERZ14207373_FASTA_SSU_OTU.tsv
# start grab for MGYA00661779
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661779/file/ERZ14207375_FASTA_SSU_OTU.tsv
# start grab for MGYA00661778
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661778/file/ERZ14207376_FASTA_SSU_OTU.tsv
# start grab for MGYA00661776
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661776/file/ERZ14207377_FASTA_SSU_OTU.tsv
# start grab for MGYA00661774
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661774/file/ERZ14207378_FASTA_SSU_OTU.tsv
# start grab for MGYA00661772
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661772/file/ERZ14207379_FASTA_SSU_OTU.tsv
# start grab for MGYA00661771
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661771/file/ERZ14207381_FASTA_SSU_OTU.tsv
# start grab for MGYA00661769
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661769/file/ERZ14207382_FASTA_SSU_OTU.tsv
# start grab for MGYA00661768
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661768/file/ERZ14207384_FASTA_SSU_OTU.tsv
# start grab for MGYA00661767
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661767/file/ERZ14207385_FASTA_SSU_OTU.tsv
# start grab for MGYA00661766
# no analysis found for [1, ['MGYA00661766']]
# start grab for MGYA00661764
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661764/file/ERZ14207387_FASTA_SSU_OTU.tsv
# start grab for MGYA00661763
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661763/file/ERZ14207388_FASTA_SSU_OTU.tsv
# start grab for MGYA00661761
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661761/file/ERZ14207365_FASTA_SSU_OTU.tsv
# start grab for MGYA00661760
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661760/file/ERZ14207235_FASTA_SSU_OTU.tsv
# start grab for MGYA00661759
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661759/file/ERZ14207236_FASTA_SSU_OTU.tsv
# start grab for MGYA00661757
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661757/file/ERZ14207242_FASTA_SSU_OTU.tsv
# start grab for MGYA00661755
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661755/file/ERZ14207243_FASTA_SSU_OTU.tsv
# start grab for MGYA00661753
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661753/file/ERZ14207244_FASTA_SSU_OTU.tsv
# start grab for MGYA00661752
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661752/file/ERZ14207245_FASTA_SSU_OTU.tsv
# start grab for MGYA00661750
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661750/file/ERZ14207246_FASTA_SSU_OTU.tsv
# start grab for MGYA00661747
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661747/file/ERZ14207248_FASTA_SSU_OTU.tsv
# start grab for MGYA00661746
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661746/file/ERZ14207249_FASTA_SSU_OTU.tsv
# start grab for MGYA00661744
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661744/file/ERZ14207250_FASTA_SSU_OTU.tsv
# start grab for MGYA00661742
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661742/file/ERZ14207261_FASTA_SSU_OTU.tsv
# start grab for MGYA00661739
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661739/file/ERZ14207247_FASTA_SSU_OTU.tsv
# start grab for MGYA00661737
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661737/file/ERZ14207251_FASTA_SSU_OTU.tsv
# start grab for MGYA00661734
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661734/file/ERZ14207252_FASTA_SSU_OTU.tsv
# start grab for MGYA00661732
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661732/file/ERZ14207253_FASTA_SSU_OTU.tsv
# start grab for MGYA00661729
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661729/file/ERZ14207254_FASTA_SSU_OTU.tsv
# start grab for MGYA00661728
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661728/file/ERZ14207255_FASTA_SSU_OTU.tsv
# start grab for MGYA00661727
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661727/file/ERZ14207259_FASTA_SSU_OTU.tsv
# start grab for MGYA00661725
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661725/file/ERZ14207263_FASTA_SSU_OTU.tsv
# start grab for MGYA00661724
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661724/file/ERZ14207265_FASTA_SSU_OTU.tsv
# start grab for MGYA00661722
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661722/file/ERZ14207267_FASTA_SSU_OTU.tsv
# start grab for MGYA00661720
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661720/file/ERZ14207238_FASTA_SSU_OTU.tsv
# start grab for MGYA00661717
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661717/file/ERZ14207241_FASTA_SSU_OTU.tsv
# start grab for MGYA00661715
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661715/file/ERZ14207260_FASTA_SSU_OTU.tsv
# start grab for MGYA00661712
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661712/file/ERZ14207262_FASTA_SSU_OTU.tsv
# start grab for MGYA00661710
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661710/file/ERZ14207264_FASTA_SSU_OTU.tsv
# start grab for MGYA00661707
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661707/file/ERZ14207266_FASTA_SSU_OTU.tsv
# start grab for MGYA00661705
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661705/file/ERZ14207268_FASTA_SSU_OTU.tsv
# start grab for MGYA00661703
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661703/file/ERZ14207269_FASTA_SSU_OTU.tsv
# start grab for MGYA00661701
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661701/file/ERZ14207270_FASTA_SSU_OTU.tsv
# start grab for MGYA00661699
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661699/file/ERZ14207271_FASTA_SSU_OTU.tsv
# start grab for MGYA00661698
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661698/file/ERZ14207272_FASTA_SSU_OTU.tsv
# start grab for MGYA00661696
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661696/file/ERZ14207273_FASTA_SSU_OTU.tsv
# start grab for MGYA00661695
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661695/file/ERZ14207274_FASTA_SSU_OTU.tsv
# start grab for MGYA00661693
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661693/file/ERZ14207237_FASTA_SSU_OTU.tsv
# start grab for MGYA00661691
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661691/file/ERZ14207239_FASTA_SSU_OTU.tsv
# start grab for MGYA00661689
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661689/file/ERZ14207275_FASTA_SSU_OTU.tsv
# start grab for MGYA00661688
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661688/file/ERZ14207276_FASTA_SSU_OTU.tsv
# start grab for MGYA00661686
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661686/file/ERZ14207277_FASTA_SSU_OTU.tsv
# start grab for MGYA00661684
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661684/file/ERZ14207278_FASTA_SSU_OTU.tsv
# start grab for MGYA00661683
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661683/file/ERZ14207279_FASTA_SSU_OTU.tsv
# start grab for MGYA00661681
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661681/file/ERZ14207280_FASTA_SSU_OTU.tsv
# start grab for MGYA00661679
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661679/file/ERZ14207282_FASTA_SSU_OTU.tsv
# start grab for MGYA00661676
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661676/file/ERZ14207283_FASTA_SSU_OTU.tsv
# start grab for MGYA00661674
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661674/file/ERZ14207284_FASTA_SSU_OTU.tsv
# start grab for MGYA00661673
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661673/file/ERZ14207287_FASTA_SSU_OTU.tsv
# start grab for MGYA00661671
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661671/file/ERZ14207289_FASTA_SSU_OTU.tsv
# start grab for MGYA00661670
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661670/file/ERZ14207292_FASTA_SSU_OTU.tsv
# start grab for MGYA00661668
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661668/file/ERZ14207296_FASTA_SSU_OTU.tsv
# start grab for MGYA00661667
# no analysis found for [1, ['MGYA00661667']]
# start grab for MGYA00661664
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661664/file/ERZ14207281_FASTA_SSU_OTU.tsv
# start grab for MGYA00661661
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661661/file/ERZ14207288_FASTA_SSU_OTU.tsv
# start grab for MGYA00661658
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661658/file/ERZ14207290_FASTA_SSU_OTU.tsv
# start grab for MGYA00661655
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661655/file/ERZ14207291_FASTA_SSU_OTU.tsv
# start grab for MGYA00661653
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661653/file/ERZ14207294_FASTA_SSU_OTU.tsv
# start grab for MGYA00661651
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661651/file/ERZ14207297_FASTA_SSU_OTU.tsv
# start grab for MGYA00661649
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661649/file/ERZ14207298_FASTA_SSU_OTU.tsv
# start grab for MGYA00661647
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661647/file/ERZ14207299_FASTA_SSU_OTU.tsv
# start grab for MGYA00661645
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661645/file/ERZ14207285_FASTA_SSU_OTU.tsv
# start grab for MGYA00661643
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661643/file/ERZ14207286_FASTA_SSU_OTU.tsv
# start grab for MGYA00661638
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661638/file/ERZ14207293_FASTA_SSU_OTU.tsv
# start grab for MGYA00661633
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661633/file/ERZ14207300_FASTA_SSU_OTU.tsv
# start grab for MGYA00661630
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661630/file/ERZ14207301_FASTA_SSU_OTU.tsv
# start grab for MGYA00661628
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661628/file/ERZ14207295_FASTA_SSU_OTU.tsv
# start grab for MGYA00661627
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661627/file/ERZ14207256_FASTA_SSU_OTU.tsv
# start grab for MGYA00661625
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661625/file/ERZ14207257_FASTA_SSU_OTU.tsv
# start grab for MGYA00661623
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661623/file/ERZ14207258_FASTA_SSU_OTU.tsv
# start grab for MGYA00661622
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00661622/file/ERZ14207240_FASTA_SSU_OTU.tsv
# start grab for MGYA00653740
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653740/file/ERZ14207220_FASTA_SSU_OTU.tsv
# start grab for MGYA00653733
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653733/file/ERZ14207232_FASTA_SSU_OTU.tsv
# start grab for MGYA00653713
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653713/file/ERZ14207231_FASTA_SSU_OTU.tsv
# start grab for MGYA00653712
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653712/file/ERZ14207234_FASTA_SSU_OTU.tsv
# start grab for MGYA00653709
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653709/file/ERZ14207233_FASTA_SSU_OTU.tsv
# start grab for MGYA00653682
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653682/file/ERZ14207230_FASTA_SSU_OTU.tsv
# start grab for MGYA00653654
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653654/file/ERZ14207229_FASTA_SSU_OTU.tsv
# start grab for MGYA00653622
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653622/file/ERZ14207228_FASTA_SSU_OTU.tsv
# start grab for MGYA00653603
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653603/file/ERZ14207227_FASTA_SSU_OTU.tsv
# start grab for MGYA00653569
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653569/file/ERZ14207226_FASTA_SSU_OTU.tsv
# start grab for MGYA00653537
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653537/file/ERZ14207225_FASTA_SSU_OTU.tsv
# start grab for MGYA00653514
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653514/file/ERZ14207224_FASTA_SSU_OTU.tsv
# start grab for MGYA00653476
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653476/file/ERZ14207223_FASTA_SSU_OTU.tsv
# start grab for MGYA00653448
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653448/file/ERZ14207222_FASTA_SSU_OTU.tsv
# start grab for MGYA00653415
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653415/file/ERZ14207221_FASTA_SSU_OTU.tsv
# start grab for MGYA00653412
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653412/file/ERZ14207303_FASTA_SSU_OTU.tsv
# start grab for MGYA00653410
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653410/file/ERZ14207304_FASTA_SSU_OTU.tsv
# start grab for MGYA00653409
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653409/file/ERZ14207305_FASTA_SSU_OTU.tsv
# start grab for MGYA00653407
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653407/file/ERZ14207306_FASTA_SSU_OTU.tsv
# start grab for MGYA00653405
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653405/file/ERZ14207307_FASTA_SSU_OTU.tsv
# start grab for MGYA00653403
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653403/file/ERZ14207308_FASTA_SSU_OTU.tsv
# start grab for MGYA00653401
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653401/file/ERZ14207309_FASTA_SSU_OTU.tsv
# start grab for MGYA00653400
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653400/file/ERZ14207219_FASTA_SSU_OTU.tsv
# start grab for MGYA00653399
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653399/file/ERZ14207310_FASTA_SSU_OTU.tsv
# start grab for MGYA00653397
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653397/file/ERZ14207311_FASTA_SSU_OTU.tsv
# start grab for MGYA00653396
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653396/file/ERZ14207312_FASTA_SSU_OTU.tsv
# start grab for MGYA00653395
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653395/file/ERZ14207313_FASTA_SSU_OTU.tsv
# start grab for MGYA00653394
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653394/file/ERZ14207314_FASTA_SSU_OTU.tsv
# start grab for MGYA00653393
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653393/file/ERZ14207315_FASTA_SSU_OTU.tsv
# start grab for MGYA00653392
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653392/file/ERZ14207316_FASTA_SSU_OTU.tsv
# start grab for MGYA00653391
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653391/file/ERZ14207317_FASTA_SSU_OTU.tsv
# start grab for MGYA00653390
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653390/file/ERZ14207318_FASTA_SSU_OTU.tsv
# start grab for MGYA00653388
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00653388/file/ERZ14207218_FASTA_SSU_OTU.tsv
# start grab for MGYA00653387
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00
MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160036
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160036/file/DRR060289_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159997
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159997/file/DRR060290_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160026
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160026/file/DRR060291_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160041
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160041/file/DRR060292_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160009
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160009/file/DRR060293_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160048
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160048/file/DRR060294_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160023
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160023/file/DRR060295_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160002
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160002/file/DRR060296_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160000
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160000/file/DRR060297_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160047
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160047/file/DRR060298_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160045
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160045/file/DRR060299_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160003
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160003/file/DRR060300_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160017
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160017/file/DRR060301_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160033
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160033/file/DRR060302_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160015
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160015/file/DRR060303_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160030
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160030/file/DRR060304_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160021
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160021/file/DRR060305_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159991
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159991/file/DRR060306_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160029
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160029/file/DRR060307_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160005
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160005/file/DRR060308_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159993
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159993/file/DRR060309_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160006
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160006/file/DRR060310_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160049
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160049/file/DRR060311_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159986
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159986/file/DRR060312_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160024
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160024/file/DRR060313_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159985
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159985/file/DRR060314_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160001
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160001/file/DRR060315_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160025
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160025/file/DRR060316_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160034
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160034/file/DRR060317_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160038
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160038/file/DRR060318_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160007
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160007/file/DRR060319_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159994
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159994/file/DRR060320_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160022
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160022/file/DRR060321_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160039
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160039/file/DRR060322_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159992
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159992/file/DRR060323_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160043
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160043/file/DRR060324_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160040
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160040/file/DRR060325_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160027
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160027/file/DRR060326_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160032
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160032/file/DRR060327_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160035
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160035/file/DRR060328_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160037
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160037/file/DRR060329_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160044
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160044/file/DRR060330_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159988
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159988/file/DRR060331_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160019
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160019/file/DRR060332_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00160042
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00160042/file/DRR060333_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00159998
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00159998/file/DRR060334_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00150693
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00150693/file/SRR1537307_FASTQ_SSU_OTU.tsv
# start grab for MGYA00150694
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00150694/file/SRR1537483_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143486
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143486/file/SRR5724734_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143482
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143482/file/SRR5724735_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143477
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143477/file/SRR5724736_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143469
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143469/file/SRR5724733_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143483
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143483/file/SRR5724731_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143488
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143488/file/SRR5724732_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143478
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143478/file/SRR5724730_MERGED_FASTQ_SSU_OTU.tsv
# start grab for MGYA00143475
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00143475/file/SRR5724729_MERGED_FASTQ_SSU_OTU.tsv

# %%
from functools import reduce

def MergeOnTaxaLevelFunction(taxa, runName,biomName):
    if(not os.path.isdir(f"./outputs/collection/{runName}/merged/")):
        os.mkdir(f"./outputs/collection/{runName}/merged/")
    galaxyInput_rankToMerge = taxa
    # selection from "superkingdom" "kingdom" "phylum" "class" "order" "family" "genus" "species" "all" "only counts"

    galaxyInput_countTables = runName


    mappingFromTaxaToNumber = {
        "superkingdom":1,
        "kingdom":2,
        "phylum":3,
        "class":4,
        "order":5,
        "family":6,
        "genus":7,
        "species":8,
        "all" : 10,         # to prevent key error in converting rank to number
        "only counts" : 10  # only counts and all will be handled when creating the tables
    }

    rankToMerge = mappingFromTaxaToNumber[galaxyInput_rankToMerge]

    filePaths = os.listdir(f"./outputs/collection/{runName}/{biomName}")

    #filePaths = []

    

    tables = []
    for file in filePaths:
        # Read out all Tables and remove unneccecary informations
        df = pd.read_csv(f"./outputs/collection/{runName}/{biomName}/{file}",sep="\t",header=1)
        df = df.iloc[: , 1:]
        if("taxid" in df.columns):
            df = df.drop(columns=["taxid"])
        df.columns = [file.split("/")[-1].replace(".tsv",""),"#KEY"]
        columns = df.columns.tolist()
        columns.reverse()
        df = df[columns]
        tables.append(df)
    # Merge all tables into one
    df = reduce(lambda df1,df2:pd.merge(df1,df2,on="#KEY",how="outer"),tables)
    df = df.fillna(0)
    if(galaxyInput_rankToMerge == "only counts"):
        df.to_csv(f"./outputs/collection/{runName}/merged/countTable_{biomName}.tsv",sep="\t",index=False)
    if(rankToMerge < 10):
        df2 = df
        df2 = df2.reset_index()
        for index, row in df.iterrows():
            rowRaw = row['#KEY']
            rowSplit = rowRaw.split(";")
            if(len(rowSplit) >= rankToMerge):
                df2.loc[index,"#KEY"] = rowSplit[rankToMerge-1].replace("__","_taxa_")
            else:
                df2.loc[index,"#KEY"] = "noValue"

        df2 = df2[df2["#KEY"] != "noValue"]
        df2 = df2.groupby(["#KEY"]).sum()
        df2 = df2.reset_index()
        df2 = df2.drop(columns=["index"])
        df2.to_csv(f"./outputs/collection/{runName}/merged/mergedOn_{galaxyInput_rankToMerge}_{biomName}.tsv",sep="\t",index=False)
    if(galaxyInput_rankToMerge == "all"):
        tables = []
        for i in range(1,9):
            df2 = df
            df2 = df2.reset_index()
            for index, row in df.iterrows():
                rowRaw = row['#KEY']
                rowSplit = rowRaw.split(";")
                if(len(rowSplit) >= i):
                    df2.loc[index,"#KEY"] = rowSplit[i-1].replace("__","_taxa_")
                else:
                    df2.loc[index,"#KEY"] = "noValue"
            df2 = df2[df2["#KEY"] != "noValue"]
            df2 = df2.groupby(["#KEY"]).sum()
            df2 = df2.reset_index()
            df2 = df2.drop(columns=["index"])
            tables.append(df2)
        result = pd.concat(tables)
        result.to_csv(f"./outputs/collection/{runName}/merged/mergedOn_{galaxyInput_rankToMerge}_{biomName}.tsv",sep="\t",index=False)

# %%
countFoldersForRun = os.listdir(f"./outputs/collection/{runName}")
for biom in inputBioms:
    print(biomNameMapping[biom])
    for taxa in ["superkingdom","kingdom","phylum","class","order","family","genus","species","all","only counts"]:
        MergeOnTaxaLevelFunction(taxa,runName,biomNameMapping[biom])
# Out:
# biom1
# biom2

# %%
######################################
# Decalration of Normalization Methods
######################################
from time import sleep

def Normalize_Softmax(_inputDF):
    # works same as in galaxy
    for column in _inputDF:
        if(column != "#KEY"):
            _inputDF[column] = _inputDF[column] / np.sum(_inputDF[column])
            _inputDF[column] = _inputDF[column] * 100
    for column in _inputDF:
        if(column != "#KEY"):
            _inputDF[column] = np.exp(_inputDF[column]) / np.sum(np.exp(_inputDF[column]))
    return _inputDF

def Normalize_RelativeAbundance(_inputDF):
    for column in _inputDF:
        if(column != "#KEY"):
            _inputDF[column] = _inputDF[column] / np.sum(_inputDF[column])
    return _inputDF

def Normalize_Sigmoid(_inputDF):
    for column in _inputDF:
        if(column != "#KEY"):
            _inputDF[column] = _inputDF[column] / np.sum(_inputDF[column])
    for column in _inputDF:
        if(column != "#KEY"):
            _inputDF[column] = (((1 / (1 + np.exp(_inputDF[column]))) - 0.5) * 2)
    return _inputDF


import numpy as np
import subprocess

def Normalize_CSS(_inputDF):
    # read table
    header = _inputDF.columns
    index = _inputDF.index
    # save table without index

    _inputDF.to_csv(f"./RData/table",sep="\t",index=False,float_format='{:.6f}'.format,header=False)

    subprocess.call("Rscript test.R",shell=True)
    
    # reload table
    _inputDF = pd.read_csv("RData/table_out",sep="\t",header=0)
    _inputDF.columns = header
    _inputDF.index = index
    return _inputDF

    #return normalized_df

def Normalize_TMM_CONORM(_inputDF):
    return conorm.tmm(_inputDF)

def Normalize_TMM_Galaxy(_inputDF):
    _inputDF = _inputDF.rename_axis('GeneID')

    #save as count Table
    _inputDF.to_csv(f"./RData/count_table",sep="\t",index=True,float_format='{:.6f}'.format,header=True)

    # create factorFile
    fileNames = list(_inputDF.columns.values)
    factors = []
    for i in range(len(fileNames)):
        if(i % 2 == 0):
            factors.append("WT")
        else:
            factors.append("Mut")
    
    _inputDF = pd.DataFrame({"Sample":fileNames, "Genotype":factors})
    _inputDF.to_csv(f"./RData/factor_table",sep="\t",index=False,float_format='{:.6f}'.format,header=True)
    subprocess.call(f"Rscript limma_voom.R -R output\out -o output -m RData\\count_table -f RData\\factor_table -D Mut,WT -x -l 0.0 -p 0.05 -d BH -G 10 -n TMM")
    _inputDF = pd.read_csv('output\\limma-voom_normcounts',sep="\t", header=0,index_col="GeneID")
    _inputDF = _inputDF.rename_axis('#KEY')

    return _inputDF

def Normalize_RLE_Galaxy(_inputDF):
    _inputDF = _inputDF.rename_axis('GeneID')
    _inputDF = _inputDF + 1
    #save as count Table
    _inputDF.to_csv(f"./RData/count_table",sep="\t",index=True,float_format='{:.6f}'.format,header=True)
    
    # add 1 to all counts, to prevent RLE to result in NA, beacause it is based on log
   
    # create factorFile
    fileNames = list(_inputDF.columns.values)
    factors = []
    for i in range(len(fileNames)):
        if(i % 2 == 0):
            factors.append("WT")
        else:
            factors.append("Mut")
    
    _inputDF = pd.DataFrame({"Sample":fileNames, "Genotype":factors})
    _inputDF.to_csv(f"./RData/factor_table",sep="\t",index=False,float_format='{:.6f}'.format,header=True)
    subprocess.call(f"Rscript limma_voom.R -R output\out -o output -m RData\\count_table -f RData\\factor_table -D Mut,WT -x -l 0.0 -p 0.05 -d BH -G 10 -n RLE")
    _inputDF = pd.read_csv('output\\limma-voom_normcounts',sep="\t", header=0,index_col="GeneID")
    _inputDF = _inputDF.rename_axis('#KEY')

    return _inputDF

# %%
from time import sleep
######################
# Normalize all Tables
######################
#pd.options.display.float_format = '{:,.6f}'.format
if(not os.path.isdir(f"./outputs/collection/{runName}/normalized/")):
    os.mkdir(f"./outputs/collection/{runName}/normalized/")

tablesToBeNormalized = os.listdir("outputs\\collection\\run_01\\merged")

failedList = []
successList = []

goodList = []

exeptions = []

for table in tablesToBeNormalized:
    print(table)
    # 
    for method in ["Normalize_Softmax","Normalize_RelativeAbundance","Normalize_CSS","Normalize_TMM_Galaxy","Normalize_RLE_Galaxy"]:
        #try:
            print(method)
            filelist = []
            #delete files from other functions
            for directory in ["RData","output"]:
                filelist = [ f for f in os.listdir(directory)]
                for f in filelist:
                    os.remove(os.path.join(directory, f))
            df = pd.read_csv(f'outputs\collection\\run_01\\merged\\{table}',sep="\t", header=0,index_col="#KEY")
            # go through all columns and remove those with 0 counts
            for c in df.columns:
                if(df[c].sum() == 0):
                    print(f"removed column {c}")
                    df = df.drop(columns=c)
            func = globals()[method]
            df = func(df)
            df.to_csv(f"./outputs/collection/{runName}/normalized/{table}_{method}.tsv",sep="\t",float_format='{:.6f}'.format)
            selfBiom = "biom1"
            pair="biom2"
            if("biom2" in table):
                pair = "biom1"
                selfBiom = "biom2"
            
            if(f'{method}_{table.replace(selfBiom,pair)}' in successList):
                goodList.append(f'{method}_{table.replace(selfBiom,"Both")}')

            successList.append(f'{method}_{table}')

        #except Exception as e:
            #exeptions.append(e)
            #failedList.append(f'{method}_{table}')
goodList
# Out:
# countTable_biom1.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# countTable_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_all_biom1.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_all_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_class_biom1.tsv
# Normalize_Softmax
# removed column MGYA00653397-SRS5061631
# Normalize_RelativeAbundance
# removed column MGYA00653397-SRS5061631
# Normalize_CSS
# removed column MGYA00653397-SRS5061631
# Normalize_TMM_Galaxy
# removed column MGYA00653397-SRS5061631
# Normalize_RLE_Galaxy
# removed column MGYA00653397-SRS5061631
# mergedOn_class_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_family_biom1.tsv
# Normalize_Softmax
# removed column MGYA00653397-SRS5061631
# Normalize_RelativeAbundance
# removed column MGYA00653397-SRS5061631
# Normalize_CSS
# removed column MGYA00653397-SRS5061631
# Normalize_TMM_Galaxy
# removed column MGYA00653397-SRS5061631
# Normalize_RLE_Galaxy
# removed column MGYA00653397-SRS5061631
# mergedOn_family_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_genus_biom1.tsv
# Normalize_Softmax
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661774-SRS5061771
# Normalize_RelativeAbundance
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661774-SRS5061771
# Normalize_CSS
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661774-SRS5061771
# Normalize_TMM_Galaxy
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661774-SRS5061771
# Normalize_RLE_Galaxy
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661774-SRS5061771
# mergedOn_genus_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_kingdom_biom1.tsv
# Normalize_Softmax
# removed column MGYA00653397-SRS5061631
# Normalize_RelativeAbundance
# removed column MGYA00653397-SRS5061631
# Normalize_CSS
# removed column MGYA00653397-SRS5061631
# Normalize_TMM_Galaxy
# removed column MGYA00653397-SRS5061631
# Normalize_RLE_Galaxy
# removed column MGYA00653397-SRS5061631
# mergedOn_kingdom_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_order_biom1.tsv
# Normalize_Softmax
# removed column MGYA00653397-SRS5061631
# Normalize_RelativeAbundance
# removed column MGYA00653397-SRS5061631
# Normalize_CSS
# removed column MGYA00653397-SRS5061631
# Normalize_TMM_Galaxy
# removed column MGYA00653397-SRS5061631
# Normalize_RLE_Galaxy
# removed column MGYA00653397-SRS5061631
# mergedOn_order_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_phylum_biom1.tsv
# Normalize_Softmax
# removed column MGYA00653397-SRS5061631
# Normalize_RelativeAbundance
# removed column MGYA00653397-SRS5061631
# Normalize_CSS
# removed column MGYA00653397-SRS5061631
# Normalize_TMM_Galaxy
# removed column MGYA00653397-SRS5061631
# Normalize_RLE_Galaxy
# removed column MGYA00653397-SRS5061631
# mergedOn_phylum_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_species_biom1.tsv
# Normalize_Softmax
# removed column MGYA00150962-SRS1027291
# removed column MGYA00151019-SRS1027353
# removed column MGYA00151086-SRS1027328
# removed column MGYA00151159-SRS1396305
# removed column MGYA00168183-SRS2647126
# removed column MGYA00653377-SRS5061639
# removed column MGYA00653380-SRS5061634
# removed column MGYA00653385-SRS5061640
# removed column MGYA00653387-SRS5061648
# removed column MGYA00653394-SRS5061638
# removed column MGYA00653395-SRS5061632
# removed column MGYA00653396-SRS5061647
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653399-SRS5061626
# removed column MGYA00653401-SRS5061627
# removed column MGYA00653405-SRS5061633
# removed column MGYA00653409-SRS5061628
# removed column MGYA00653410-SRS5061646
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661622-SRS5098352
# removed column MGYA00661623-SRS5098353
# removed column MGYA00661668-SRS5098375
# removed column MGYA00661673-SRS5098377
# removed column MGYA00661674-SRS5098346
# removed column MGYA00661683-SRS5098338
# removed column MGYA00661688-SRS5098388
# removed column MGYA00661693-SRS5098343
# removed column MGYA00661695-SRS5098378
# removed column MGYA00661699-SRS5098340
# removed column MGYA00661701-SRS5098385
# removed column MGYA00661724-SRS5098333
# removed column MGYA00661737-SRS5098387
# removed column MGYA00661742-SRS5098386
# removed column MGYA00661744-SRS5098366
# removed column MGYA00661746-SRS5098365
# removed column MGYA00661757-SRS5098332
# removed column MGYA00661760-SRS5098347
# removed column MGYA00661761-SRS5061792
# removed column MGYA00661767-SRS5061782
# removed column MGYA00661768-SRS5061777
# removed column MGYA00661769-SRS5061779
# removed column MGYA00661772-SRS5061781
# removed column MGYA00661774-SRS5061771
# removed column MGYA00661778-SRS5061773
# removed column MGYA00661780-SRS5061789
# removed column MGYA00661782-SRS5061780
# removed column MGYA00661783-SRS5061791
# removed column MGYA00661784-SRS5061788
# removed column MGYA00661785-SRS5061785
# removed column MGYA00661792-SRS5061794
# Normalize_RelativeAbundance
# removed column MGYA00150962-SRS1027291
# removed column MGYA00151019-SRS1027353
# removed column MGYA00151086-SRS1027328
# removed column MGYA00151159-SRS1396305
# removed column MGYA00168183-SRS2647126
# removed column MGYA00653377-SRS5061639
# removed column MGYA00653380-SRS5061634
# removed column MGYA00653385-SRS5061640
# removed column MGYA00653387-SRS5061648
# removed column MGYA00653394-SRS5061638
# removed column MGYA00653395-SRS5061632
# removed column MGYA00653396-SRS5061647
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653399-SRS5061626
# removed column MGYA00653401-SRS5061627
# removed column MGYA00653405-SRS5061633
# removed column MGYA00653409-SRS5061628
# removed column MGYA00653410-SRS5061646
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661622-SRS5098352
# removed column MGYA00661623-SRS5098353
# removed column MGYA00661668-SRS5098375
# removed column MGYA00661673-SRS5098377
# removed column MGYA00661674-SRS5098346
# removed column MGYA00661683-SRS5098338
# removed column MGYA00661688-SRS5098388
# removed column MGYA00661693-SRS5098343
# removed column MGYA00661695-SRS5098378
# removed column MGYA00661699-SRS5098340
# removed column MGYA00661701-SRS5098385
# removed column MGYA00661724-SRS5098333
# removed column MGYA00661737-SRS5098387
# removed column MGYA00661742-SRS5098386
# removed column MGYA00661744-SRS5098366
# removed column MGYA00661746-SRS5098365
# removed column MGYA00661757-SRS5098332
# removed column MGYA00661760-SRS5098347
# removed column MGYA00661761-SRS5061792
# removed column MGYA00661767-SRS5061782
# removed column MGYA00661768-SRS5061777
# removed column MGYA00661769-SRS5061779
# removed column MGYA00661772-SRS5061781
# removed column MGYA00661774-SRS5061771
# removed column MGYA00661778-SRS5061773
# removed column MGYA00661780-SRS5061789
# removed column MGYA00661782-SRS5061780
# removed column MGYA00661783-SRS5061791
# removed column MGYA00661784-SRS5061788
# removed column MGYA00661785-SRS5061785
# removed column MGYA00661792-SRS5061794
# Normalize_CSS
# removed column MGYA00150962-SRS1027291
# removed column MGYA00151019-SRS1027353
# removed column MGYA00151086-SRS1027328
# removed column MGYA00151159-SRS1396305
# removed column MGYA00168183-SRS2647126
# removed column MGYA00653377-SRS5061639
# removed column MGYA00653380-SRS5061634
# removed column MGYA00653385-SRS5061640
# removed column MGYA00653387-SRS5061648
# removed column MGYA00653394-SRS5061638
# removed column MGYA00653395-SRS5061632
# removed column MGYA00653396-SRS5061647
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653399-SRS5061626
# removed column MGYA00653401-SRS5061627
# removed column MGYA00653405-SRS5061633
# removed column MGYA00653409-SRS5061628
# removed column MGYA00653410-SRS5061646
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661622-SRS5098352
# removed column MGYA00661623-SRS5098353
# removed column MGYA00661668-SRS5098375
# removed column MGYA00661673-SRS5098377
# removed column MGYA00661674-SRS5098346
# removed column MGYA00661683-SRS5098338
# removed column MGYA00661688-SRS5098388
# removed column MGYA00661693-SRS5098343
# removed column MGYA00661695-SRS5098378
# removed column MGYA00661699-SRS5098340
# removed column MGYA00661701-SRS5098385
# removed column MGYA00661724-SRS5098333
# removed column MGYA00661737-SRS5098387
# removed column MGYA00661742-SRS5098386
# removed column MGYA00661744-SRS5098366
# removed column MGYA00661746-SRS5098365
# removed column MGYA00661757-SRS5098332
# removed column MGYA00661760-SRS5098347
# removed column MGYA00661761-SRS5061792
# removed column MGYA00661767-SRS5061782
# removed column MGYA00661768-SRS5061777
# removed column MGYA00661769-SRS5061779
# removed column MGYA00661772-SRS5061781
# removed column MGYA00661774-SRS5061771
# removed column MGYA00661778-SRS5061773
# removed column MGYA00661780-SRS5061789
# removed column MGYA00661782-SRS5061780
# removed column MGYA00661783-SRS5061791
# removed column MGYA00661784-SRS5061788
# removed column MGYA00661785-SRS5061785
# removed column MGYA00661792-SRS5061794
# Normalize_TMM_Galaxy
# removed column MGYA00150962-SRS1027291
# removed column MGYA00151019-SRS1027353
# removed column MGYA00151086-SRS1027328
# removed column MGYA00151159-SRS1396305
# removed column MGYA00168183-SRS2647126
# removed column MGYA00653377-SRS5061639
# removed column MGYA00653380-SRS5061634
# removed column MGYA00653385-SRS5061640
# removed column MGYA00653387-SRS5061648
# removed column MGYA00653394-SRS5061638
# removed column MGYA00653395-SRS5061632
# removed column MGYA00653396-SRS5061647
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653399-SRS5061626
# removed column MGYA00653401-SRS5061627
# removed column MGYA00653405-SRS5061633
# removed column MGYA00653409-SRS5061628
# removed column MGYA00653410-SRS5061646
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661622-SRS5098352
# removed column MGYA00661623-SRS5098353
# removed column MGYA00661668-SRS5098375
# removed column MGYA00661673-SRS5098377
# removed column MGYA00661674-SRS5098346
# removed column MGYA00661683-SRS5098338
# removed column MGYA00661688-SRS5098388
# removed column MGYA00661693-SRS5098343
# removed column MGYA00661695-SRS5098378
# removed column MGYA00661699-SRS5098340
# removed column MGYA00661701-SRS5098385
# removed column MGYA00661724-SRS5098333
# removed column MGYA00661737-SRS5098387
# removed column MGYA00661742-SRS5098386
# removed column MGYA00661744-SRS5098366
# removed column MGYA00661746-SRS5098365
# removed column MGYA00661757-SRS5098332
# removed column MGYA00661760-SRS5098347
# removed column MGYA00661761-SRS5061792
# removed column MGYA00661767-SRS5061782
# removed column MGYA00661768-SRS5061777
# removed column MGYA00661769-SRS5061779
# removed column MGYA00661772-SRS5061781
# removed column MGYA00661774-SRS5061771
# removed column MGYA00661778-SRS5061773
# removed column MGYA00661780-SRS5061789
# removed column MGYA00661782-SRS5061780
# removed column MGYA00661783-SRS5061791
# removed column MGYA00661784-SRS5061788
# removed column MGYA00661785-SRS5061785
# removed column MGYA00661792-SRS5061794
# Normalize_RLE_Galaxy
# removed column MGYA00150962-SRS1027291
# removed column MGYA00151019-SRS1027353
# removed column MGYA00151086-SRS1027328
# removed column MGYA00151159-SRS1396305
# removed column MGYA00168183-SRS2647126
# removed column MGYA00653377-SRS5061639
# removed column MGYA00653380-SRS5061634
# removed column MGYA00653385-SRS5061640
# removed column MGYA00653387-SRS5061648
# removed column MGYA00653394-SRS5061638
# removed column MGYA00653395-SRS5061632
# removed column MGYA00653396-SRS5061647
# removed column MGYA00653397-SRS5061631
# removed column MGYA00653399-SRS5061626
# removed column MGYA00653401-SRS5061627
# removed column MGYA00653405-SRS5061633
# removed column MGYA00653409-SRS5061628
# removed column MGYA00653410-SRS5061646
# removed column MGYA00653412-SRS5061645
# removed column MGYA00661622-SRS5098352
# removed column MGYA00661623-SRS5098353
# removed column MGYA00661668-SRS5098375
# removed column MGYA00661673-SRS5098377
# removed column MGYA00661674-SRS5098346
# removed column MGYA00661683-SRS5098338
# removed column MGYA00661688-SRS5098388
# removed column MGYA00661693-SRS5098343
# removed column MGYA00661695-SRS5098378
# removed column MGYA00661699-SRS5098340
# removed column MGYA00661701-SRS5098385
# removed column MGYA00661724-SRS5098333
# removed column MGYA00661737-SRS5098387
# removed column MGYA00661742-SRS5098386
# removed column MGYA00661744-SRS5098366
# removed column MGYA00661746-SRS5098365
# removed column MGYA00661757-SRS5098332
# removed column MGYA00661760-SRS5098347
# removed column MGYA00661761-SRS5061792
# removed column MGYA00661767-SRS5061782
# removed column MGYA00661768-SRS5061777
# removed column MGYA00661769-SRS5061779
# removed column MGYA00661772-SRS5061781
# removed column MGYA00661774-SRS5061771
# removed column MGYA00661778-SRS5061773
# removed column MGYA00661780-SRS5061789
# removed column MGYA00661782-SRS5061780
# removed column MGYA00661783-SRS5061791
# removed column MGYA00661784-SRS5061788
# removed column MGYA00661785-SRS5061785
# removed column MGYA00661792-SRS5061794
# mergedOn_species_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_superkingdom_biom1.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# mergedOn_superkingdom_biom2.tsv
# Normalize_Softmax
# Normalize_RelativeAbundance
# Normalize_CSS
# Normalize_TMM_Galaxy
# Normalize_RLE_Galaxy
# ['Normalize_Softmax_countTable_Both.tsv',
#  'Normalize_RelativeAbundance_countTable_Both.tsv',
#  'Normalize_CSS_countTable_Both.tsv',
#  'Normalize_TMM_Galaxy_countTable_Both.tsv',
#  'Normalize_RLE_Galaxy_countTable_Both.tsv',
#  'Normalize_Softmax_mergedOn_all_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_all_Both.tsv',
#  'Normalize_CSS_mergedOn_all_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_all_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_all_Both.tsv',
#  'Normalize_Softmax_mergedOn_class_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_class_Both.tsv',
#  'Normalize_CSS_mergedOn_class_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_class_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_class_Both.tsv',
#  'Normalize_Softmax_mergedOn_family_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_family_Both.tsv',
#  'Normalize_CSS_mergedOn_family_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_family_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_family_Both.tsv',
#  'Normalize_Softmax_mergedOn_genus_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_genus_Both.tsv',
#  'Normalize_CSS_mergedOn_genus_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_genus_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_genus_Both.tsv',
#  'Normalize_Softmax_mergedOn_kingdom_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_kingdom_Both.tsv',
#  'Normalize_CSS_mergedOn_kingdom_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_kingdom_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_kingdom_Both.tsv',
#  'Normalize_Softmax_mergedOn_order_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_order_Both.tsv',
#  'Normalize_CSS_mergedOn_order_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_order_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_order_Both.tsv',
#  'Normalize_Softmax_mergedOn_phylum_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_phylum_Both.tsv',
#  'Normalize_CSS_mergedOn_phylum_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_phylum_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_phylum_Both.tsv',
#  'Normalize_Softmax_mergedOn_species_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_species_Both.tsv',
#  'Normalize_CSS_mergedOn_species_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_species_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_species_Both.tsv',
#  'Normalize_Softmax_mergedOn_superkingdom_Both.tsv',
#  'Normalize_RelativeAbundance_mergedOn_superkingdom_Both.tsv',
#  'Normalize_CSS_mergedOn_superkingdom_Both.tsv',
#  'Normalize_TMM_Galaxy_mergedOn_superkingdom_Both.tsv',
#  'Normalize_RLE_Galaxy_mergedOn_superkingdom_Both.tsv']

# %%
len(goodList)
# Out:
# 50

# %%
if(not os.path.isdir(f"./outputs/collection/{runName}/deepMicroInput/")):
    os.mkdir(f"./outputs/collection/{runName}/deepMicroInput/")

pairs = {}
pairsNames = {}
for merge in ["superkingdom","kingdom","phylum","class","order","family","genus","species","all","only counts"]:
    fileNameStart = f"mergedOn_{merge}_"
    if(merge == "only counts"):
        fileNameStart = f"countTable_"
    for normalizationMethod in ["Normalize_Softmax","Normalize_RelativeAbundance","Normalize_CSS","Normalize_TMM_Galaxy","Normalize_RLE_Galaxy"]:
        pair = []
        pairNames = []
        for biom in inputBioms:
            biomName = biomNameMapping[biom]
            fileName = f'{fileNameStart}{biomName}.tsv_{normalizationMethod}.tsv'
            if(os.path.exists(f'outputs/collection/{runName}/normalized/{fileName}')):
                #print(f'outputs/collection/{runName}/normalized/{fileName}')
                df = pd.read_csv(f'outputs/collection/{runName}/normalized/{fileName}',sep="\t",header=0,index_col="#KEY")
                pair.append(df)
                pairNames.append(biomName)
        pairs[f'{fileNameStart}_{normalizationMethod}'] = pair
        pairsNames[f'{fileNameStart}_{normalizationMethod}'] = pairNames

# %%
from sklearn.preprocessing import LabelEncoder



for pair in pairs.keys():
    le = LabelEncoder()
    samlesToBiomMapping = {}
    dfList = []
    i = 0
    for df in pairs[pair]:
        df = df.rename_axis('phylum')
        df = df.reset_index()
        df = df.drop(df[df['phylum'] == 'Unassigned'].index)
        df = df.set_index('phylum')
        for c in df.columns:
            samlesToBiomMapping[c] = pairsNames[pair][i]
        dfList.append(df)
        i += 1
    df = dfList[0].join(dfList[1],on='phylum',how="outer")                          ############################################# add outer join
    df = df.fillna(0)
    # remove samples without counts
    for c in df.columns:
        if(df[c].sum() == 0):
            print(f"removed column {c} from {pair}")
            df = df.drop(columns=c)
    df = df.transpose()
    df.to_csv(f"./outputs/collection/{runName}/deepMicroInput/{pair}_X",sep=",",header=False,index=False,float_format='{:.6f}'.format)
    df = df.reset_index()
    df = df.rename(columns={"index":"phylum"})
    df = df.replace({"phylum": samlesToBiomMapping})
    df = df["phylum"]
    le.fit(df)
    #df["phylum"] = list(le.transform(df))
    df = pd.DataFrame(list(le.transform(df)))
    df.to_csv(f"./outputs/collection/{runName}/deepMicroInput/{pair}_Y",sep=",",header=False,index=False,float_format='{:.6f}'.format)
df
# Out:
# removed column MGYA00160006-DRS049568 from mergedOn_species__Normalize_Softmax
# removed column MGYA00185679-ERS2517172 from mergedOn_species__Normalize_Softmax
# removed column MGYA00185696-ERS2517202 from mergedOn_species__Normalize_Softmax
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 969  1
# 970  1
# 971  1
# 972  1
# 973  1
#
# [974 rows x 1 columns]

# %%
# Out:
# 0      biom1
# 1      biom1
# 2      biom1
# 3      biom1
# 4      biom1
#        ...
# 969    biom2
# 970    biom2
# 971    biom2
# 972    biom2
# 973    biom2
# Name: phylum, Length: 974, dtype: object
